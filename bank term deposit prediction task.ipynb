# %% [markdown]
# ### **Import Needed Modules**

# %% [markdown]
# ### **Exploratory Data Analysis and Wrangling**

# %% [markdown]
# **Download dataset from this [here](https://www.kaggle.com/datasets/thedevastator/bank-term-deposit-predictions) and read the data description**
#
# **Read data**

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %% [markdown]
# **Get sample**

# %%
# Train data sample
# Out:
#        age            job  marital  education default  balance housing loan  \
# 37903   34    blue-collar  married  secondary      no     2447     yes   no
# 27646   57  self-employed   single    primary      no     6056     yes   no
# 12450   35     technician  married  secondary      no      251     yes  yes
# 21178   58  self-employed  married   tertiary      no      584     yes   no
# 11100   55        retired  married  secondary      no       31      no   no
# 27225   44    blue-collar  married    unknown      no     1149     yes   no
# 42034   57      housemaid  married   tertiary      no     2326      no   no
# 24696   43     management  married   tertiary      no     2767     yes   no
# 4025    42     management   single   tertiary      no    10561      no   no
# 36832   27         admin.   single  secondary      no      292     yes   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# 37903  cellular   14   may       330         2     -1         0  unknown   no
# 27646  cellular   21   nov        18         5     -1         0  unknown   no
# 12450   unknown    1   jul       128         3     -1         0  unknown   no
# 21178  cellular   14   aug       124         3     -1         0  unknown   no
# 11100   unknown   18   jun        72         1     -1         0  unknown   no
# 27225  cellular   21   nov        67         5     -1         0  unknown   no
# 42034  cellular   28   oct       207         1    194         1  success  yes
# 24696  cellular   17   nov       374         1    186         7  failure   no
# 4025    unknown   16   may       243         2     -1         0  unknown   no
# 36832  cellular   12   may        53         9    362         8    other   no

# %%
# Test data sample
# Out:
#       age          job   marital  education default  balance housing loan  \
# 1124   37   technician   married    unknown      no      189      no   no
# 1189   34   technician    single  secondary      no      201      no   no
# 99     31   unemployed    single    primary      no      406      no   no
# 3724   37    housemaid  divorced  secondary      no     1040     yes   no
# 3253   39  blue-collar   married    unknown      no      157     yes   no
# 1737   59    housemaid   married  secondary      no      345      no   no
# 4185   31   management   married   tertiary      no      271      no   no
# 3503   27     services    single  secondary      no      266      no  yes
# 2683   33    housemaid   married    primary      no      212     yes   no
# 4492   32   technician    single  secondary      no      309     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# 1124  cellular    1   oct       238         1    107         2  success  yes
# 1189  cellular   22   jul       257         2     -1         0  unknown   no
# 99    cellular    4   feb       736         1     -1         0  unknown  yes
# 3724  cellular   13   may       199         1    173         2  failure   no
# 3253   unknown   30   may        99         6     -1         0  unknown   no
# 1737   unknown    9   jun        38         1     -1         0  unknown   no
# 4185  cellular   18   nov        89         1     -1         0  unknown   no
# 3503  cellular    7   jul       232         1     -1         0  unknown   no
# 2683  cellular   11   jul       260         2     -1         0  unknown   no
# 4492  cellular   16   apr       346         1    234         3  failure   no

# %% [markdown]
# **Get data informaion**

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %% [markdown]
# #### **Age Feature - The age of the customer.**

# %%
# Get statistical analysis for age column
# Out:
# count    45211.000000
# mean        40.936210
# std         10.618762
# min         18.000000
# 25%         33.000000
# 50%         39.000000
# 75%         48.000000
# max         95.000000
# Name: age, dtype: float64

# %% [markdown]
# **Plot hisogram to show the frequency distribution of a ages**
#
#     Note: use palette='viridis' in all of your graphs for better color representation.

# %%
# Out:
# /tmp/ipykernel_42/2994252962.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ax = sns.histplot(train_df['age'], bins=50, kde=True, palette='viridis')

# %% [markdown]
# #### **Job Feature - The occupation/employment status of the customer.**

# %% [markdown]
# **Show the distribution of job column**

# %%
# Out:
# job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: count, dtype: int64

# %% [markdown]
# **Rename "unknown" values with "others"**

# %%
# Out:
# job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# others            288
# Name: count, dtype: int64

# %% [markdown]
# **Plot the distribution**

# %% [markdown]
# **Also, Don't forget to rename these values in test data.**

# %%
# Out:
# job
# management       969
# blue-collar      946
# technician       768
# admin.           478
# services         417
# retired          230
# self-employed    183
# entrepreneur     168
# unemployed       128
# housemaid        112
# student           84
# others            38
# Name: count, dtype: int64

# %% [markdown]
# #### **Marital-Status Feature - The marital status of the customer.**

# %% [markdown]
# **Show the distribution of marital-status column**

# %%
# Out:
# marital
# married     27214
# single      12790
# divorced     5207
# Name: count, dtype: int64

# %% [markdown]
# **Plot the distribution**

# %% [markdown]
# #### **Educational Feature - The education level attained by the customer.**

# %% [markdown]
# **Show the distribution of Education column**

# %%
# Out:
# education
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: count, dtype: int64

# %% [markdown]
# **Rename "unknown" values with "others"**

# %%
# Out:
# education
# secondary    23202
# tertiary     13301
# primary       6851
# others        1857
# Name: count, dtype: int64

# %% [markdown]
# **Show the distribution of education column**

# %% [markdown]
# **Also, Don't forget to rename these values in test data.**

# %%
# Out:
# education
# secondary    2306
# tertiary     1350
# primary       678
# others        187
# Name: count, dtype: int64

# %% [markdown]
# #### **Credit in Default Feature - Whether the customer has credit in default or not.**

# %%
# Out:
# default
# no     44396
# yes      815
# Name: count, dtype: int64

# %% [markdown]
# **This feature is worthless, the "yes" values is so poor, so I'll drop it.**

# %%
# drop default column in train data

# %% [markdown]
# **Also, don't forget drop this column from test data.**

# %%
# drop default column in test data

# %% [markdown]
# #### **Balance Feature - The balance in the customer's account.**

# %%
# Out:
# count     45211.000000
# mean       1362.272058
# std        3044.765829
# min       -8019.000000
# 25%          72.000000
# 50%         448.000000
# 75%        1428.000000
# max      102127.000000
# Name: balance, dtype: float64

# %% [markdown]
# **Plot the graph using [kdeplot](https://seaborn.pydata.org/generated/seaborn.kdeplot.html) from seaborn**

# %%
# Out:
# /tmp/ipykernel_42/1190658190.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(train_df['balance'], palette='viridis')

# %% [markdown]
#     What do you say about this graph?

# %% [markdown]
# -

# %% [markdown]
# **Check for values under zero**

# %%
# Out:
# 7280

# %% [markdown]
# **Define the percentile threshold for outliers - 95%**
# - **All the data that above 95% will be considered outliers**

# %%
# Out:
# 95th Percentile Value: 5768
# Number of Potential Outliers: 2260

# %% [markdown]
# - **The maximum value of 102127 is considerably higher than the 95th percentile (5768).**
# - **Drop the values that above 5768.**

# %% [markdown]
# **Plot the Balance graph again using [kdeplot](https://seaborn.pydata.org/generated/seaborn.kdeplot.html) from seaborn**

# %%
# Out:
# /tmp/ipykernel_42/1190658190.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(train_df['balance'], palette='viridis')

# %% [markdown]
# **We have solved the skew in right side**

# %% [markdown]
# **Plot the [boxplot](https://seaborn.pydata.org/generated/seaborn.boxplot.html) of this column using seaborn**

# %% [markdown]
# **Define the percentile threshold for outliers - 5%**
# - **All the data that under 5% will be considered outliers**

# %%
# Out:
# 5th Percentile Value: -191
# Number of Potential Outliers: 2142

# %% [markdown]
# - **The minimum value of -8019 is considerably lower than the 5th percentile (-191).**
# - **Drop the values that under -191.**

# %% [markdown]
# **Plot the Balance graph again using [kdeplot](https://seaborn.pydata.org/generated/seaborn.kdeplot.html) from seaborn**

# %%
# Out:
# /tmp/ipykernel_42/1190658190.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(train_df['balance'], palette='viridis')

# %% [markdown]
#     What do you think about the graph now?

# %% [markdown]
# **Plot the [boxplot](https://seaborn.pydata.org/generated/seaborn.boxplot.html) again using seaborn**

# %% [markdown]
# #### **Housing Loan Feature - Whether the customer has a housing loan or not.**

# %%
# Out:
# housing
# yes    22448
# no     18352
# Name: count, dtype: int64

# %% [markdown]
# #### **Loan Feature - Whether the customer has a loan or not.**

# %%
# Out:
# loan
# no     34462
# yes     6338
# Name: count, dtype: int64

# %% [markdown]
# #### **Contact Feature - Type of communication used to contact customers**

# %%
# Out:
# contact
# cellular     26530
# unknown      11625
# telephone     2645
# Name: count, dtype: int64

# %% [markdown]
# **Rename "unknown" values with "others".**

# %%
# Out:
# contact
# cellular     26530
# others       11625
# telephone     2645
# Name: count, dtype: int64

# %% [markdown]
# **Also, Don't forget to rename these values in test data.**

# %%
# Out:
# contact
# cellular     2896
# others       1324
# telephone     301
# Name: count, dtype: int64

# %% [markdown]
# #### **Day Feature - Day of the month when customers were last contacted.**

# %%
# Out:
# day
# 20    2425
# 18    2059
# 17    1789
# 5     1769
# 6     1768
# 21    1762
# 8     1702
# 14    1664
# 7     1654
# 28    1645
# 29    1597
# 19    1550
# 15    1533
# 12    1469
# 13    1445
# 9     1423
# 30    1422
# 11    1338
# 4     1322
# 16    1309
# 2     1173
# 27     960
# 3      959
# 26     892
# 22     832
# 23     816
# 25     768
# 31     573
# 10     474
# 24     417
# 1      291
# Name: count, dtype: int64

# %% [markdown]
# #### **Month Feature - last contact month of year.**

# %%
# Out:
# month
# may    12310
# jul     6233
# aug     5763
# jun     4793
# nov     3387
# apr     2711
# feb     2454
# jan     1322
# oct      668
# sep      533
# mar      430
# dec      196
# Name: count, dtype: int64

# %% [markdown]
# #### **Duration Feature - last contact duration, in seconds**

# %% [markdown]
# **Display statistical analysis for Duration column**

# %%
# Out:
# count    40800.000000
# mean       257.625931
# std        257.278864
# min          0.000000
# 25%        103.000000
# 50%        180.000000
# 75%        318.000000
# max       3881.000000
# Name: duration, dtype: float64

# %%
# Out:
# /tmp/ipykernel_42/3320358875.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ax = sns.histplot(train_df['duration'], bins=50, kde=True, palette='viridis')

# %% [markdown]
# #### **Campaign Feature - number of contacts performed during this campaign and for this client**

# %%
# Out:
# count    40800.000000
# mean         2.760490
# std          3.079005
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         58.000000
# Name: campaign, dtype: float64

# %%
# Out:
# /tmp/ipykernel_42/225366631.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ax = sns.histplot(train_df['campaign'], bins=30, kde=True, palette='viridis')

# %% [markdown]
# #### **Passed Days - number of days that passed by after the client was last contacted from a previous campaign (-1 means client was not previously contacted)**

# %%
# Get the values that doesn't -1 
filtered_data = train_df[train_df['pdays'] != -1]

# %%
# Get statistical summary
# Out:
# count    7494.000000
# mean      224.477315
# std       115.930819
# min         1.000000
# 25%       131.000000
# 50%       195.000000
# 75%       326.000000
# max       871.000000
# Name: pdays, dtype: float64

# %%
# Out:
# /tmp/ipykernel_42/2682749744.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ax = sns.histplot(filtered_data['pdays'], bins=30, kde=True, palette='viridis')

# %% [markdown]
# #### **Previous Contacts - number of contacts performed before this campaign and for this client.**

# %%
# Out:
# previous
# 0      33306
# 1       2522
# 2       1896
# 3       1035
# 4        651
# 5        418
# 6        255
# 7        187
# 8        126
# 9         79
# 10        62
# 11        61
# 12        41
# 13        31
# 14        18
# 15        18
# 17        13
# 16        12
# 19        10
# 20         7
# 23         7
# 22         6
# 24         5
# 27         5
# 18         4
# 21         4
# 29         3
# 25         3
# 38         2
# 37         2
# 30         2
# 51         1
# 275        1
# 26         1
# 58         1
# 28         1
# 32         1
# 40         1
# 55         1
# 41         1
# Name: count, dtype: int64

# %% [markdown]
# **This feature is useless, the most of values have 0 value, so drop it**

# %% [markdown]
# **Also, don't forget drop this column from test data.**

# %% [markdown]
# #### **Previous Outcome - outcome of the previous marketing campaign**

# %%
# Out:
# poutcome
# unknown    33311
# failure     4405
# other       1678
# success     1406
# Name: count, dtype: int64

# %% [markdown]
# **This feature is useless, the most of values are unknowns, so drop it**

# %% [markdown]
# **Also, don't forget drop this column from test data.**

# %% [markdown]
# #### **Target Column - has the client subscribed a term deposit.**

# %%
# Out:
# y
# no     35971
# yes     4829
# Name: count, dtype: int64

# %% [markdown]
# #### **Create a Label Encoder model to convert the categorical values into numeric**

# %%
# Display new_data head values
# Out:
#    age  job  marital  education  balance  housing  loan  contact  day  month  \
# 0   40    4        1          3     2310        1     0        1    4      8
# 1   26   10        2          2      219        1     0        1    4      8
# 2   15    2        1          2      192        1     1        1    4      8
# 3   29    1        1          0     1694        1     0        1    4      8
# 4   15    5        2          0      191        0     0        1    4      8
#
#    duration  campaign  pdays  y
# 0       261         0      0  0
# 1       151         0      0  0
# 2        76         0      0  0
# 3        92         0      0  0
# 4       198         0      0  0

# %% [markdown]
# **Also, don't forget encode test data**

# %%
# Out:
#       age  job  marital  education  balance  housing  loan  contact  day  \
# 0      11   11        1          1     1475        0     0        0   18
# 1      14    8        1          2     2030        1     1        0   10
# 2      16    4        2          3     1303        1     0        0   15
# 3      11    4        1          3     1352        1     1        1    2
# 4      40    1        1          2      274        1     0        1    4
# ...   ...  ...      ...        ...      ...      ...   ...      ...  ...
# 4516   14    8        1          2      119        1     0        0   29
# 4517   38    7        1          3        0        1     1        1    8
# 4518   38   10        1          2      558        0     0        0   18
# 4519    9    1        1          2     1187        0     0        0    5
# 4520   25    2        2          3     1186        1     1        0    2
#
#       month  duration  campaign  pdays  y
# 0        10        75         0      0  0
# 1         8       216         0    228  0
# 2         0       181         0    219  0
# 3         6       195         3      0  0
# 4         8       222         0      0  0
# ...     ...       ...       ...    ... ..
# 4516      5       325         4      0  0
# 4517      8       149         0      0  0
# 4518      1       147        10      0  0
# 4519      3       125         3    140  0
# 4520      0       341         1    161  0
#
# [4521 rows x 14 columns]

# %% [markdown]
# #### **Get Features Correlation**

# %% [markdown]
# ## **Data Preprocessing for ML Models**

# %% [markdown]
# #### **Define Features X and Target y**

# %% [markdown]
# - **For train data**

# %% [markdown]
# - **For test data**

# %% [markdown]
# ## **Machine Learning Algorithms**

# %% [markdown]
# #### **Logistic Regression**
# [Link](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html)

# %%
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %% [markdown]
# **Display training score**

# %%
# Out:
# 0.8885539215686274

# %% [markdown]
# **Display testing score**

# %%
# Out:
# 0.8854235788542358

# %% [markdown]
# **Get prediction**

# %% [markdown]
# **Plot Confusion Matrix**

# %% [markdown]
# **Print Classification Report**

# %%
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94      4000
#            1       0.51      0.10      0.17       521
#
#     accuracy                           0.89      4521
#    macro avg       0.70      0.55      0.56      4521
# weighted avg       0.85      0.89      0.85      4521

# %% [markdown]
# $$\mathrm{Share \space your \space notebook \space on \space KAGGLE}$$
# $$\mathrm{Best \space Wishes..♡}$$
